# %%
import pandas as pd
import matplotlib as pl
import mpld3 as d3

# %%
dem_candidates = pd.read_excel('StateCandidates/DemPrimary_StateCandidates.xlsx', header=1)

# %%
dem_candidates.head()
# Out:
#                     Office Name Office Type            Candidate Name  County  \
# 0         RAILROAD COMMISSIONER   STATEWIDE  ROBERTO R. "BETO" ALONZO     NaN
# 1         RAILROAD COMMISSIONER   STATEWIDE         CHRYSTA CASTAÑEDA     NaN
# 2         RAILROAD COMMISSIONER   STATEWIDE               KELLY STONE     NaN
# 3         RAILROAD COMMISSIONER   STATEWIDE               MARK WATSON     NaN
# 4  CHIEF JUSTICE, SUPREME COURT   STATEWIDE         AMY CLARK MEACHUM     NaN
#
#                       Email       Party  \
# 0    ALONZOPC2003@YAHOO.COM  DEMOCRATIC
# 1  INFO@CHRYSTAFORTEXAS.COM  DEMOCRATIC
# 2       INFO@VOTEKSTONE.COM  DEMOCRATIC
# 3                       NaN  DEMOCRATIC
# 4        AMY@AMYMEACHUM.COM  DEMOCRATIC
#
#                                            Address        City  State  \
# 0              400 S ZANG 816 \nDALLAS TEXAS 75208      DALLAS  TEXAS
# 1         P O BOX 225035 \nDALLAS TEXAS 75222-5035      DALLAS  TEXAS
# ...

# %%
dem_candidates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 456 entries, 0 to 455
# Data columns (total 12 columns):
# Office Name       456 non-null object
# Office Type       456 non-null object
# Candidate Name    456 non-null object
# County            0 non-null float64
# Email             391 non-null object
# Party             456 non-null object
# Address           456 non-null object
# City              452 non-null object
# State             452 non-null object
# Occupation        456 non-null object
# Incumbent         456 non-null object
# Status            445 non-null object
# dtypes: float64(1), object(11)
# memory usage: 42.9+ KB

# %%
rep_candidates = pd.read_excel('StateCandidates/RepubPrimary_StateCandidates.xlsx', header=1)

# %%
rep_candidates.head()
# Out:
#                                         Office Name Office Type  \
# 0                             RAILROAD COMMISSIONER   STATEWIDE
# 1                             RAILROAD COMMISSIONER   STATEWIDE
# 2                      CHIEF JUSTICE, SUPREME COURT   STATEWIDE
# 3  JUSTICE, SUPREME COURT, PLACE 6 - UNEXPIRED TERM   STATEWIDE
# 4                   JUSTICE, SUPREME COURT, PLACE 7   STATEWIDE
#
#        Candidate Name County                      Email       Party  \
# 0         RYAN SITTON    NaN  RYAN.SITTON@RRC.TEXAS.GOV  REPUBLICAN
# 1  JAMES "JIM" WRIGHT    NaN                        NaN  REPUBLICAN
# 2        NATHAN HECHT    NaN            NLHECHT@ATT.NET  REPUBLICAN
# 3          JANE BLAND    NaN   JUDGEJANEBLAND@GMAIL.COM  REPUBLICAN
# 4           JEFF BOYD    NaN                        NaN  REPUBLICAN
#
#                                        Address      City  State  \
# 0           PO BOX 341566 \nAUSTIN TEXAS 78734    AUSTIN  TEXAS
# ...

# %%
rep_candidates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 549 entries, 0 to 548
# Data columns (total 12 columns):
# Office Name       549 non-null object
# Office Type       549 non-null object
# Candidate Name    549 non-null object
# County            2 non-null object
# Email             399 non-null object
# Party             549 non-null object
# Address           549 non-null object
# City              395 non-null object
# State             395 non-null object
# Occupation        549 non-null object
# Incumbent         549 non-null object
# Status            546 non-null object
# dtypes: object(12)
# memory usage: 51.6+ KB

# %%
primary_candidates = dem_candidates.append(rep_candidates, sort=True)

# %%
primary_candidates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1005 entries, 0 to 548
# Data columns (total 12 columns):
# Address           1005 non-null object
# Candidate Name    1005 non-null object
# City              847 non-null object
# County            2 non-null object
# Email             790 non-null object
# Incumbent         1005 non-null object
# Occupation        1005 non-null object
# Office Name       1005 non-null object
# Office Type       1005 non-null object
# Party             1005 non-null object
# State             847 non-null object
# Status            991 non-null object
# dtypes: object(12)
# memory usage: 102.1+ KB

# %%
primary_candidates.sort_values(by=['Office Name', 'Party'] ).to_csv('StateCandidates/AllPrimaryCandidates.csv')

# %%
primary_candidates.to_csv('StateCandidates/AllPrimaryCandidates.csv')

# %%
primary_candidates.head()
# Out:
#                                            Address            Candidate Name  \
# 0              400 S ZANG 816 \nDALLAS TEXAS 75208  ROBERTO R. "BETO" ALONZO
# 1         P O BOX 225035 \nDALLAS TEXAS 75222-5035         CHRYSTA CASTAÑEDA
# 2  326 N LBJ DR SUITE 262 \nSAN MARCOS TEXAS 78666               KELLY STONE
# 3     5851 MCCOMMAS BOULEVARD \nDALLAS TEXAS 75206               MARK WATSON
# 4               P O BOX 27351 \nAUSTIN TEXAS 78755         AMY CLARK MEACHUM
#
#          City County                     Email Incumbent Occupation  \
# 0      DALLAS    NaN    ALONZOPC2003@YAHOO.COM        NO   ATTORNEY
# 1      DALLAS    NaN  INFO@CHRYSTAFORTEXAS.COM        NO   ATTORNEY
# 2  SAN MARCOS    NaN       INFO@VOTEKSTONE.COM        NO   EDUCATOR
# 3      DALLAS    NaN                       NaN        NO   ATTORNEY
# 4      AUSTIN    NaN        AMY@AMYMEACHUM.COM        NO      JUDGE
#
#                     Office Name Office Type       Party  State      Status
# ...
